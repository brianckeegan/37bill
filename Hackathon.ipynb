# %% [markdown]
# # March 22 hackathon

# %% [markdown]
# # Questions

# %% [markdown]
# * How does proximity to transit relate to income?
# * What are factors leading to higher vehicle ownership?
# * Opportunities for mode shift -- shifting from places that should have low ownership but have high ownership?
# * How much are individuals spending on transportation and how does that vary

# %%
import pandas as pd
from collections import Counter
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
mass_zipcodes = [('01001','02791'),('05501','05544')]

# %%
grid_data_description = pd.read_csv('grid_quarters_public_metadata.csv',encoding='utf8')
grid_data_columns = data_description['Field']
grid_data_description
# Out:
#          Field                         Field Name  \
# 0       seq_id                        Sequence ID
# 1     g250m_id                            Grid ID
# 2         hh10                   Households, 2010
# 3      quarter                        Sample Date
# 4      veh_tot                     Total Vehicles
# 5     pass_veh                 Passenger Vehicles
# 6    ovrlp_pct           Mileage Estimate Overlap
# 7     pass_geo                 Passenger Geocoded
# 8     best_geo           Passenger Best Estimates
# 9     pass_zip             Passenger Zip Assigned
# 10   pass_muni            Passenger Muni Assigned
# 11     veh_phh             Vehicles per Household
# 12  mipdaypass   Miles per Day Passenger Vehicles
# 13  mipday_phh            Household Miles per Day
# 14  mipdaybest                 Miles per Day-Best
# 15      veh_lo               Low Mileage Vehicles
# 16   veh_medlo        Medium-Low Mileage Vehicles
# 17   veh_medhi       Medium-High Mileage Vehicles
# 18      veh_hi              High Mileage Vehicles
# 19     veh_vhi         Very High Mileage Vehicles
# 20    comm_veh                Commercial Vehicles
# 21    comm_geo                Commercial Geocoded
# 22    comm_zip            Commercial Zip Assigned
# 23   comm_muni           Commercial Muni Assigned
# 24  mipdaycomm  Miles per Day Commercial Vehicles
# 25     mpg_eff         Average Fuel Economy (MPG)
# 26  glpdaypass            Fuel per Day, Passenger
# 27  co2eqv_day             CO2 per Day, Passenger
#
#                                           Description
# 0                          Unique ID for this record.
# 1           Unique integer ID for 250 meter grid cell
# 2   Estimated number of households in the grid cel...
# 3   Date of record. The vehicle-level dataset is s...
# 4   Total Registered Vehicles (pass_veh) + (comm_veh)
# 5   Total Passenger Vehicles (pass_geo + pass_zip_...
# 6   The composite mileage estimate overlap for all...
# 7   Count of passenger vehicles assigned to this g...
# 8   Count of geocoded passenger vehicles that cons...
# 9   Count of ungeocoded passenger vehicles within ...
# 10  Count of ungeocoded passenger vehicles within ...
# 11  Registered passenger vehicle per household. To...
# 12  Average daily mileage for passenger vehicles w...
# 13  Passenger vehicle miles travelled per househol...
# 14  Average daily mileage for "best" estimate vehi...
# 15  Geocoded Passenger Vehicles with valid mileage...
# 16  Geocoded Passenger Vehicles with valid mileage...
# 17  Geocoded Passenger Vehicles with valid mileage...
# 18  Geocoded Passenger Vehicles with valid mileage...
# 19  Geocoded Passenger Vehicles with valid mileage...
# 20  Total Estimated Commercial Vehicles (comm_geo ...
# 21  Count of Commercial Vehicles assigned to this ...
# 22  Count of ungeocoded commercial vehicles within...
# 23  Count of ungeocoded commercial vehicles within...
# 24           Average Commercial Vehicle Miles per Day
# 25  Average fuel economy for passenger vehicles wi...
# 26  Average daily fuel (gasoline or diesel) consum...
# 27  Daily greenhouse gas emissions (kilograms of C...
#
# [28 rows x 3 columns]

# %%
rae_data_description = pd.read_csv('rae_public_metadata.csv',encoding='utf8')
rae_data_columns = rae_data_description['Field']
rae_data_description
# Out:
#           Field             Field Name  \
# 0     record_id             Record ID
# 1        vin_id             Vehicle ID
# 2      plate_id               Plate ID
# 3         me_id    Mileage Estimate ID
# 4    owner_type             Owner Type
# 5    start_odom         Start Odometer
# 6    start_date             Start date
# 7      end_date               End Date
# 8    insp_match       Inspection Match
# 9    ovrlp_days          Record Length
# 10   daysbtnins  Mileage Estimate Days
# 11    ovrlp_pct        Percent Overlap
# 12   mi_per_day          Miles per Day
# 13      muni_id           Municipal ID
# 14      veh_zip               Zip Code
# 15    insp_year  Mileage Estimate Year
# 16   model_year          Vehicle Model
# 17         make           Vehicle Make
# 18        model          Vehicle Model
# 19     veh_type           Vehicle Type
# 20       mcycle             Motorcycle
# 21       hybrid                Hybrid
# 22       curbwt            Curb Weight
# 23         msrp                   MSRP
# 24      mpg2008           Fuel Economy
# 25         fuel              Fuel Type
# 26      mpg_adj           Adjusted MPG
# 27  gal_per day         Daily Fuel Use
# 28   co2eqv_day             co2eqv_day
# 29      q1_2008                q1_2009
# 30      q2_2008                q2_2009
# 31      q3_2008                q3_2009
# 32      q4_2008                q4_2009
# 33      q1_2009                q1_2009
# 34      q2_2009                q2_2009
# 35      q3_2009                q3_2009
# 36      q4_2009                q4_2009
# 37      q1_2010                q1_2010
# 38      q2_2010                q2_2010
# 39      q3_2010                q3_2010
# 40      q4_2010                q4_2010
# 41      q1_2011                q1_2011
# 42      q2_2011                q2_2011
# 43      q3_2011                q3_2011
# 44      q4_2011                q4_2011
#
#                                           Description
# 0   Unique ID for this record. Each record represe...
# 1   Randomly assigned unique integer that replaces...
# 2   Randomly assigned unique integer that replaces...
# 3   ID field for the mileage estimate associated w...
# 4   1: Noncommercial Passenger Vehicles; 2: Commer...
# 5   Odometer reading from the inspection at the be...
# 6   Start date for this registration and estimates...
# 7   End date for this registration and estimates r...
# 8   Indicates if there is a mileage estimate for t...
# 9                       Number of days in this record
# 10  Number of days between the two inspections tha...
# 11  The length of this record as a percent of the ...
# 12  Estimated daily mileage for this vehicle durin...
# 13  Numeric ID number (DOR ID) for municipality wh...
# 14  Zip code where vehicle is garaged.  A value of...
# 15  Calendar year containing the end date of the m...
# 16  Vehicle Model Year as reported by a commercial...
# 17  Vehicle make as reported by a commercial vehic...
# 18  Vehicle Model as reported by a commercial vehi...
# 19  Type of Vehicle: Car, Truck, SUV, Wagon, Van, ...
# 20                      Flag for motorcycles; 1= yes
# 21         Flag for hybrid electric vehicles; 1 = yes
# 22  Total weight of vehicle with standard equipmen...
# 23  Manufacturers Suggested Retail Price, as repor...
# 24  Average (city/highway) fuel economy from 2008 ...
# 25  Type of fuel consumed: Gasoline, Diesel, Flexf...
# 26  Fuel economy rating adjusted to account for de...
# 27  Estimated average daily fuel consumption, base...
# 28  Greenhouse gas emissions, in kilograms of CO2 ...
# 29  Indicates if this record is valid on the media...
# 30  Indicates if this record is valid on the media...
# 31  Indicates if this record is valid on the media...
# 32  Indicates if this record is valid on the media...
# 33  Indicates if this record is valid on the media...
# 34  Indicates if this record is valid on the media...
# 35  Indicates if this record is valid on the media...
# 36  Indicates if this record is valid on the media...
# 37  Indicates if this record is valid on the media...
# 38  Indicates if this record is valid on the media...
# 39  Indicates if this record is valid on the media...
# 40  Indicates if this record is valid on the media...
# 41  Indicates if this record is valid on the media...
# 42  Indicates if this record is valid on the media...
# 43  Indicates if this record is valid on the media...
# 44  Indicates if this record is valid on the media...
#
# [45 rows x 3 columns]

# %%
grid = pd.read_csv('grid_quarters_public_noheader.csv',encoding='utf8',header=None)
rae = pd.read_csv('rae_public_noheader.csv',encoding='utf8',header=None)

rae.columns = list(rae_data_columns)
rae.head()

grid.columns = list(grid_data_columns)
grid.head()

# %%
#rae.columns = list(rae_data_columns)
rae = rae.fillna(0)
rae.head().T
# Out:
#                       0           1           2           3               4
# record_id             2           4           7           9              10
# vin_id                1           1           2           2               3
# plate_id        5346561     5346561     6614801     6614801         6417306
# me_id          12800589    11498668    12800590    11498669        12800591
# owner_type            1           1           1           1               1
# start_odom            0           0           0           0               0
# start_date   2011-11-07  2009-08-27  2011-11-19  2008-07-01      2011-12-06
# end_date     2011-12-31  2009-09-01  2011-12-31  2008-07-02      2011-12-31
# insp_match            f           f           f           f               f
# ovrlp_days           54           5          42           1              25
# daysbtnins           54         609          42         183              25
# ovrlp_pct             0           0           0           0               0
# mi_per_day            0           0           0           0               0
# muni_id             325         325         288         288             145
# veh_zip            1089        1089        1776        1776            2364
# insp_year          2011        2009        2011        2008            2011
# model_year         2008        2008        2008        2008            2005
# make            Hyundai     Hyundai       Acura       Acura       Chevrolet
# model            Sonata      Sonata         Mdx         Mdx  Silverado-1500
# veh_type            Car         Car         SUV         SUV           Truck
# mcycle                0           0           0           0               0
# hybrid                0           0           0           0               0
# curbwt             3500        3500        4500        4500            5000
# msrp              23000       23000       40000       40000           32000
# mpg2008              23          23          17          17              15
# fuel           Gasoline    Gasoline    Gasoline    Gasoline        Gasoline
# mpg_adj           21.65       22.54          16          17           13.29
# gal_per day           0           0           0           0               0
# co2eqv_day            0           0           0           0               0
# q1_2008               0           0           0           0               0
# q2_2008               0           0           0           0               0
# q3_2008               0           0           0           0               0
# q4_2008               0           0           0           0               0
# q1_2009               0           0           0           0               0
# q2_2009               0           0           0           0               0
# q3_2009               0           0           0           0               0
# q4_2009               0           0           0           0               0
# q1_2010               0           0           0           0               0
# q2_2010               0           0           0           0               0
# q3_2010               0           0           0           0               0
# q4_2010               0           0           0           0               0
# q1_2011               0           0           0           0               0
# q2_2011               0           0           0           0               0
# q3_2011               0           0           0           0               0
# q4_2011               1           0           0           0               0
# veh_zip_fix       01089       01089       01776       01776           02364
#
# [46 rows x 5 columns]

# %%
def zip_fixer(num):
    if len(str(num))==4:
        return '0'+str(num)
    else:
        return str(num)

# %%
rae['veh_zip_fix'] = rae['veh_zip'].apply(lambda x:zip_fixer(x))
rae.head()
# Out:
#    record_id  vin_id  plate_id     me_id  owner_type  start_odom  start_date  \
# 0          2       1   5346561  12800589           1         NaN  2011-11-07
# 1          4       1   5346561  11498668           1         NaN  2009-08-27
# 2          7       2   6614801  12800590           1         NaN  2011-11-19
# 3          9       2   6614801  11498669           1         NaN  2008-07-01
# 4         10       3   6417306  12800591           1         NaN  2011-12-06
#
#      end_date insp_match  ovrlp_days  daysbtnins  ovrlp_pct  mi_per_day  \
# 0  2011-12-31          f          54          54        NaN           0
# 1  2009-09-01          f           5         609        NaN           0
# 2  2011-12-31          f          42          42        NaN           0
# 3  2008-07-02          f           1         183        NaN           0
# 4  2011-12-31          f          25          25        NaN           0
#
#    muni_id  veh_zip  insp_year  model_year       make           model  \
# 0      325     1089       2011        2008    Hyundai          Sonata
# 1      325     1089       2009        2008    Hyundai          Sonata
# 2      288     1776       2011        2008      Acura             Mdx
# 3      288     1776       2008        2008      Acura             Mdx
# 4      145     2364       2011        2005  Chevrolet  Silverado-1500
#
#   veh_type
# 0      Car ...
# 1      Car ...
# 2      SUV ...
# 3      SUV ...
# 4    Truck ...
#
# [5 rows x 46 columns]

# %%
rae_gb_zip = rae.groupby('veh_zip')

# %%
gb = rae_gb_zip.agg({'msrp':{'vehicles':len,
                             'msrp_mean':np.mean,
                             'msrp_min':min,
                             'msrp_max':max,
                             'msrp_std':np.std},
                     'mpg2008':{'mpg_mean':np.mean,
                                'mpg_min':min,
                                'mpg_max':max,
                                'mpg_std':np.std},
                     'curbwt':{'curbwt_mean':np.mean},
                     'hybrid':{'hybrid_frac':lambda x:sum(x)/float(len(x))*100.},
                     'mcycle':{'mcycle_frac':lambda x:sum(x)/float(len(x))*100.},
                     'veh_type':{'car_frac':lambda x:sum(x == 'Car')/float(len(x))*100,
                                 'truck_frac':lambda x:sum(x == 'Truck')/float(len(x))*100.,
                                 'suv_frac':lambda x:sum(x == 'SUV')/float(len(x))*100.},
                     'mi_per_day':{'mpd_mean':np.mean,
                                   'mpd_min':min,
                                   'mpd_max':max,
                                   'mpd_std':np.std}
                     })
gb.columns = gb.columns.droplevel(0)
gb = gb.reset_index()
gb_ma = gb[((int(mass_zipcodes[0][1]) >= gb['veh_zip']) & (int(mass_zipcodes[0][0]) <= gb['veh_zip'])) | ((int(mass_zipcodes[1][1]) >= gb['veh_zip']) & (int(mass_zipcodes[1][0]) <= gb['veh_zip']))]
gb_ma = gb.set_index('veh_zip')
gb_ma.head()
# Out:
#          mpg_min   mpg_mean  mpg_max   mpg_std  curbwt_mean  mcycle_frac  \
# veh_zip
# 0              0  17.570617       62  7.427800  3368.600880     1.375213
# 1001           0  19.207913       51  6.680228  3443.640150     0.339622
# 1002           0  22.236971       58  6.976006  3227.961555     0.072318
# 1003          13  23.047945       32  4.872629  3245.890411     0.000000
# 1004           0  12.911602       47  9.800386  3066.574586     0.000000
#
#          hybrid_frac      mpd_std     mpd_max  mpd_min   mpd_mean   car_frac  \
# veh_zip
# 0           0.891101  1479.359894  2178324.67        0  23.841568  53.335997
# 1001        0.379286   131.376089    22817.74        0  24.132722  55.435187
# 1002        3.643914   151.397890    29715.00        0  24.110388  71.457565
# 1003        0.000000   849.356583    10279.50        0  91.265616  80.821918
# 1004        1.381215    34.029444      388.38        0  23.082928  19.060773
#
#          truck_frac   suv_frac      msrp_std  msrp_max     msrp_mean  \
# veh_zip
# 0         10.743954  18.933569  15054.360902    495000  25350.078888
# 1001      12.989911  18.716379   9370.623443    261000  22880.884504
# 1002       5.608174  13.140951   7667.948366    112000  22019.362665
# 1003       0.000000  15.068493   8501.943427     58000  20726.027397
# 1004      27.624309  14.640884  15832.571791    159000  19994.475138
#
#          vehicles  msrp_min
# veh_zip
# 0         2179663         0
# 1001        40339         0
# 1002        42866         0
# 1003          146         0
# 1004          362         0
#
# [5 rows x 19 columns]

# %%
gb[(gb['frac_0_muni_id']!=0)].dropna(subset=['hybrid_frac']).sort('hybrid_frac',ascending=False).head()
# Out:
#              mpg_min   mpg_mean  mpg_max  curbwt_mean  mcycle_frac  \
# veh_zip_fix
# 85375            NaN        NaN      NaN  2900.000000          NaN
# 97218            NaN        NaN      NaN  3700.000000          NaN
# 49423            NaN  19.000000      NaN  3675.000000          NaN
# 97701            NaN  37.666667      NaN  3433.333333          NaN
# 13088             17  39.666667       51  3433.333333          NaN
#
#              hybrid_frac  frac_0_muni_id  car_frac  truck_frac  suv_frac  \
# veh_zip_fix
# 85375           1.000000        1.000000  1.000000           0         0
# 97218           1.000000        1.000000  1.000000           0         0
# 49423           0.750000        0.250000  1.000000           0         0
# 97701           0.666667        0.166667  0.833333           0         0
# 13088           0.666667        0.333333  0.666667           0         0
#
#              msrp_max     msrp_mean  vehicles  msrp_min
# veh_zip_fix
# 85375           22000  22000.000000         1     22000
# 97218           27000  27000.000000         1     27000
# 49423           30000  27750.000000         4     27000
# 97701           35000  26333.333333         6     23000
# 13088           37000  27666.666667         3     23000
#
# [5 rows x 14 columns]

# %% [markdown]
# # Read in census data

# %%
census_headers = pd.read_csv('ACS_12_5YR_DP03_metadata.csv',encoding='utf8',header=False)

estimates = [i for i in list(census_headers['GEO.id']) if 'HC01' in i]
estimates.append('GEO.id')

percentages = [i for i in list(census_headers['GEO.id']) if 'HC03' in i]
percentages.append('GEO.id')

# %%
census_df = pd.read_csv('ACS_12_5YR_DP03_with_ann.csv',encoding='utf8',header=False)
census_df.head()
# Out:
#            GEO.id  GEO.id2 GEO.display-label  HC01_VC04  HC02_VC04  HC03_VC04  \
# 0  8600000US01001     1001       ZCTA5 01001      14235        535      14235
# 1  8600000US01002     1002       ZCTA5 01002      25455       1247      25455
# 2  8600000US01003     1003       ZCTA5 01003      11242       1258      11242
# 3  8600000US01005     1005       ZCTA5 01005       4077        206       4077
# 4  8600000US01007     1007       ZCTA5 01007      11479        254      11479
#
#   HC04_VC04  HC01_VC05  HC02_VC05 HC03_VC05 HC04_VC05  HC01_VC06  HC02_VC06  \
# 0       (X)       9736        545      68.4       2.8       9710        541
# 1       (X)      16062       1136      63.1       2.7      16045       1133
# 2       (X)       4861        713      43.2       3.9       4861        713
# 3       (X)       3016        217      74.0       4.0       3003        219
# 4       (X)       8689        419      75.7       3.2       8689        419
#
#   HC03_VC06 HC04_VC06  HC01_VC07  HC02_VC07 HC03_VC07 HC04_VC07  HC01_VC08
# 0      68.2       2.8       9075        515      63.8       2.7        635 ...
# 1      63.0       2.7      14713       1048      57.8       2.7       1332 ...
# 2      43.2       3.9       3838        657      34.1       4.0       1023 ...
# 3      73.7       4.0       2714        201      66.6       3.8        289 ...
# 4      75.7       3.2       8120        446      70.7       3.6        569 ...
#
# [5 rows x 551 columns]

# %%
estimates = [i for i in list(census_headers['GEO.id']) if 'HC01' in i]
estimates.append('GEO.id2')

percentages = [i for i in list(census_headers['GEO.id']) if 'HC03' in i]
percentages.append('GEO.id2')

estimates_df = census_df[estimates]
percentages_df = census_df[percentages]

# %%
interesting = {'GEO.id2':'ZIP',
               'HC01_VC04':'Population_gt18_c',
               'HC01_VC05':'Laborer_c',
               'HC03_VC05':'Laborer_p',
               'HC01_VC08':'Unemployment_c',
               'HC03_VC08':'Unemployment_p',
               'HC01_VC15':'Females_c',
               'HC03_VC15':'Females_p',
               'HC01_VC28':'Commuters_c',
               'HC01_VC29':'Drive_alone_c',
               'HC03_VC29':'Drive_alone_p',
               'HC01_VC30':'Carpooled_c',
               'HC03_VC30':'Carpooled_p',
               'HC01_VC31':'Pub_trans_c',
               'HC03_VC31':'Pub_trans_p',
               'HC01_VC32':'Walked_c',
               'HC03_VC32':'Walked_p',
               'HC01_VC34':'Home_c',
               'HC03_VC34':'Home_p',
               'HC01_VC36':'Travel_time',
               'HC01_VC85':'Median_income',
               'HC01_VC122':'Median_male_income',
               'HC01_VC123':'Median_female_income',
               'HC01_VC127':'Civilian_pop',
               'HC01_VC131':'Uninsured_c',
               'HC03_VC131':'Uninsured_p'}

# %%
def remove_crap(element):
    try:
        element = float(element)
    except ValueError:
        element = np.nan
    return element

# %%
interesting_df = census_df[sorted(interesting.keys())]
interesting_df.columns = [interesting[i] for i in interesting_df.columns]
interesting_df = interesting_df.set_index('ZIP')
interesting_df = interesting_df.apply(lambda x: x.apply(remove_crap))
interesting_df.head()
# Out:
#       Population_gt18_c  Laborer_c  Unemployment_c  Median_male_income  \
# ZIP
# 1001              14235       9736             635               54204
# 1002              25455      16062            1332               65333
# 1003              11242       4861            1023               48274
# 1005               4077       3016             289               63456
# 1007              11479       8689             569               62309
#
#       Median_female_income  Civilian_pop  Uninsured_c  Females_c  Commuters_c  \
# ZIP
# 1001                 43884         16818          685       7694         8949
# 1002                 47111         28581          912      13011        14488
# 1003                 27868         11286          139       6202         3838
# 1005                 47656          5069           28       2031         2618
# 1007                 45639         14593          218       5701         7927
#
#       Drive_alone_c  Carpooled_c  Pub_trans_c  Walked_c  Home_c  Travel_time  \
# ZIP
# 1001           7897          608            0       226     142         19.6
# 1002           8276         1163         1427      1781    1597         20.7
# 1003            656          227           99      1761    1045         15.0
# 1005           2033          319            0        30     230         37.4
# 1007           6580          663           56        85     480         27.9
#
#       Median_income  Laborer_p  Unemployment_p  Uninsured_p  Females_p
# ZIP
# 1001          63682       68.4             4.5          4.1       7694 ...
# 1002          56175       63.1             5.2          3.2      13011 ...
# 1003         165865       43.2             9.1          1.2       6202 ...
# 1005          75856       74.0             7.1          0.6       2031 ...
# 1007          77617       75.7             5.0          1.5       5701 ...
#
# [5 rows x 25 columns]

# %% [markdown]
# # Join ZIP code data together

# %%
joined_df = interesting_df.join(gb_ma)
joined_df['gender_income_inequality'] = joined_df['Median_male_income'] - joined_df['Median_female_income']

# %% [markdown]
# # Plot distributions

# %%
figsize(10,5)
plt.scatter(gb_ma[(gb_ma['mpg_mean'] > 0) & (gb_ma['msrp_mean'] > 0)]['msrp_mean'],
            gb_ma[(gb_ma['mpg_mean'] > 0) & (gb_ma['msrp_mean'] > 0)]['mpg_mean'],
            alpha=.25,
            s=np.log(gb_ma['vehicles'])*50)
plt.xlabel('MSRP ($)',fontsize=18)
plt.ylabel('MPG',fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim((0,50))
plt.xscale('log')

# %%
counter_vehicles = Counter(gb_ma['vehicles'])

# %%
plt.scatter(counter_vehicles.keys(),counter_vehicles.values(),s=100,alpha=.25)
plt.yscale('log')
plt.xscale('log')
plt.ylabel('Number of zipcodes',fontsize=18)
plt.xlabel('Number of vehicles',fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Out:
# (array([  1.00000000e-02,   1.00000000e-01,   1.00000000e+00,
#          1.00000000e+01,   1.00000000e+02,   1.00000000e+03]),
#  <a list of 6 Text yticklabel objects>)

# %% [markdown]
# # Statistical models

# %%
joined_df.columns
# Out:
# Index([u'Population_gt18_c', u'Laborer_c', u'Unemployment_c', u'Median_male_income', u'Median_female_income', u'Civilian_pop', u'Uninsured_c', u'Females_c', u'Commuters_c', u'Drive_alone_c', u'Carpooled_c', u'Pub_trans_c', u'Walked_c', u'Home_c', u'Travel_time', u'Median_income', u'Laborer_p', u'Unemployment_p', u'Uninsured_p', u'Females_p', u'Drive_alone_p', u'Carpooled_p', u'Pub_trans_p', u'Walked_p', u'Home_p', u'mpg_min', u'mpg_mean', u'mpg_max', u'mpg_std', u'curbwt_mean', u'mcycle_frac', u'hybrid_frac', u'mpd_std', u'mpd_max', u'mpd_min', u'mpd_mean', u'car_frac', u'truck_frac', u'suv_frac', u'msrp_std', u'msrp_max', u'msrp_mean', u'vehicles', u'msrp_min'], dtype='object')

# %%
joined_df.head().T
# Out:
# ZIP                                1001           1002           1003  \
# Population_gt18_c          14235.000000   25455.000000   11242.000000
# Laborer_c                   9736.000000   16062.000000    4861.000000
# Unemployment_c               635.000000    1332.000000    1023.000000
# Median_male_income         54204.000000   65333.000000   48274.000000
# Median_female_income       43884.000000   47111.000000   27868.000000
# Civilian_pop               16818.000000   28581.000000   11286.000000
# Uninsured_c                  685.000000     912.000000     139.000000
# Females_c                   7694.000000   13011.000000    6202.000000
# Commuters_c                 8949.000000   14488.000000    3838.000000
# Drive_alone_c               7897.000000    8276.000000     656.000000
# Carpooled_c                  608.000000    1163.000000     227.000000
# Pub_trans_c                    0.000000    1427.000000      99.000000
# Walked_c                     226.000000    1781.000000    1761.000000
# Home_c                       142.000000    1597.000000    1045.000000
# Travel_time                   19.600000      20.700000      15.000000
# Median_income              63682.000000   56175.000000  165865.000000
# Laborer_p                     68.400000      63.100000      43.200000
# Unemployment_p                 4.500000       5.200000       9.100000
# Uninsured_p                    4.100000       3.200000       1.200000
# Females_p                   7694.000000   13011.000000    6202.000000
# Drive_alone_p                 88.200000      57.100000      17.100000
# Carpooled_p                    6.800000       8.000000       5.900000
# Pub_trans_p                    0.000000       9.800000       2.600000
# Walked_p                       2.500000      12.300000      45.900000
# Home_p                         1.600000      11.000000      27.200000
# mpg_min                        0.000000       0.000000      13.000000
# mpg_mean                      19.207913      22.236971      23.047945
# mpg_max                       51.000000      58.000000      32.000000
# mpg_std                        6.680228       6.976006       4.872629
# curbwt_mean                 3443.640150    3227.961555    3245.890411
# mcycle_frac                    0.339622       0.072318       0.000000
# hybrid_frac                    0.379286       3.643914       0.000000
# mpd_std                      131.376089     151.397890     849.356583
# mpd_max                    22817.740000   29715.000000   10279.500000
# mpd_min                        0.000000       0.000000       0.000000
# mpd_mean                      24.132722      24.110388      91.265616
# car_frac                       0.005544       0.007146       0.008082
# truck_frac                     0.001299       0.000561       0.000000
# suv_frac                      18.716379      13.140951      15.068493
# msrp_std                    9370.623443    7667.948366    8501.943427
# msrp_max                  261000.000000  112000.000000   58000.000000
# msrp_mean                  22880.884504   22019.362665   20726.027397
# vehicles                   40339.000000   42866.000000     146.000000
# msrp_min                       0.000000       0.000000       0.000000
# gender_income_inequality   10320.000000   18222.000000   20406.000000
#
# ZIP                               1005          1007
# Population_gt18_c          4077.000000  11479.000000
# Laborer_c                  3016.000000   8689.000000
# Unemployment_c              289.000000    569.000000
# Median_male_income        63456.000000  62309.000000
# Median_female_income      47656.000000  45639.000000
# Civilian_pop               5069.000000  14593.000000
# Uninsured_c                  28.000000    218.000000
# Females_c                  2031.000000   5701.000000
# Commuters_c                2618.000000   7927.000000
# Drive_alone_c              2033.000000   6580.000000
# Carpooled_c                 319.000000    663.000000
# Pub_trans_c                   0.000000     56.000000
# Walked_c                     30.000000     85.000000
# Home_c                      230.000000    480.000000
# Travel_time                  37.400000     27.900000
# Median_income             75856.000000  77617.000000
# Laborer_p                    74.000000     75.700000
# Unemployment_p                7.100000      5.000000
# Uninsured_p                   0.600000      1.500000
# Females_p                  2031.000000   5701.000000
# Drive_alone_p                77.700000     83.000000
# Carpooled_p                  12.200000      8.400000
# Pub_trans_p                   0.000000      0.700000
# Walked_p                      1.100000      1.100000
# Home_p                        8.800000      6.100000
# mpg_min                       0.000000      0.000000
# mpg_mean                     18.046159     18.752188
# mpg_max                      51.000000     51.000000
# mpg_std                       8.152701      7.497821
# curbwt_mean                3470.348482   3474.375615
# mcycle_frac                   0.519666      0.452164
# hybrid_frac                   1.202364      0.992100
# mpd_std                     348.542040    139.516706
# mpd_max                   33327.330000  19126.690000
# mpd_min                       0.000000      0.000000
# mpd_mean                     33.046108     27.326556
# car_frac                      0.004424      0.004730
# truck_frac                    0.002465      0.001843
# suv_frac                     18.198492     20.858047
# msrp_std                   8819.383110   8891.398093
# msrp_max                  87000.000000  98000.000000
# msrp_mean                 21759.221520  22482.299120
# vehicles                   9814.000000  37597.000000
# msrp_min                      0.000000      0.000000
# gender_income_inequality  15800.000000  16670.000000
#
# [45 rows x 5 columns]

# %%
x = pd.DataFrame({
                  'Travel_time': np.linspace(joined_df['Travel_time'].min(), joined_df['Travel_time'].max(), 100),
                  'Unemployment_p': np.linspace(joined_df['Unemployment_p'].min(), joined_df['Unemployment_p'].max(), 100),
                  'Median_income': np.linspace(joined_df['Median_income'].min(), joined_df['Median_income'].max(), 100),
                  'hybrid_frac':np.linspace(joined_df['hybrid_frac'].min(), joined_df['hybrid_frac'].max(), 100),
                  })

# %%
m1 = smf.ols('Travel_time ~ Unemployment_p + log(Median_income+1) + log(mpd_mean+1) + gender_income_inequality + car_frac',data=joined_df).fit()
print m1.summary()


#plt.scatter(joined_df['Median_income'],joined_df['Travel_time'])
#plt.plot(x['Median_income'], m1.predict(x), 'r-', alpha=0.9)

#plt.scatter(joined_df['Median_income'],joined_df['Travel_time'])
#plt.plot(np.log(x['Median_income'], m1.predict(x), 'r-', alpha=0.9)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Travel_time   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     23.96
# Date:                Sat, 22 Mar 2014   Prob (F-statistic):           1.21e-21
# Time:                        17:12:51   Log-Likelihood:                -1501.1
# No. Observations:                 508   AIC:                             3014.
# Df Residuals:                     502   BIC:                             3040.
# Df Model:                           5
# ============================================================================================
#                                coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------
# Intercept                  -38.1392      8.684     -4.392      0.000       -55.202   -21.077
# Unemployment_p               0.5659      0.102      5.552      0.000         0.366     0.766
# log(Median_income + 1)       5.3293      0.705      7.559      0.000         3.944     6.714
# log(mpd_mean + 1)            2.1279      0.930      2.289      0.023         0.301     3.954
# gender_income_inequality  2.273e-05   1.63e-05      1.395      0.164     -9.29e-06  5.48e-05
# car_frac                    -0.0817      0.022     -3.744      0.000        -0.125    -0.039
# ==============================================================================
# Omnibus:                       34.939   Durbin-Watson:                   1.580
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.867
# Skew:                          -0.330   Prob(JB):                     8.32e-20
# Kurtosis:                       4.928   Cond. No.                     9.28e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 9.28e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
joined_df['mpd_mean'].hist()

# %%
plt.scatter(joined_df['Travel_time'],np.log(joined_df['mpd_mean']+1))
